# %% [markdown]
# ### Tensorflow and keras

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#pip install tensorflow

# %%
import tensorflow as tf
from tensorflow import keras
# Out:
# 2025-11-20 14:59:55.103031: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-20 14:59:55.335071: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-20 15:00:13.454221: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-20 15:00:25.766568: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-20 15:00:25.767710: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
from tensorflow.keras.preprocessing.image import load_img

# %%
path = './clothing-dataset-small/train/t-shirt'
name = '0a85a584-cb49-4795-b2f1-7eebbf09399a.jpg'
fullname = f'{path}/{name}'

# %%
img = load_img(fullname, target_size=(299, 299))

# %%
X = np.array(img)
X.shape
# Out:
# (299, 299, 3)

# %%
X
# Out:
# array([[[ 99,  99,  87],
#         [116, 116, 104],
#         [114, 114, 102],
#         ...,
#         [ 23,  30,  46],
#         [ 23,  30,  46],
#         [ 22,  29,  45]],
#
#        [[106, 106,  94],
#         [120, 120, 108],
#         [122, 122, 110],
#         ...,
#         [ 24,  31,  47],
#         [ 23,  30,  46],
#         [ 23,  30,  46]],
#
#        [[118, 118, 106],
#         [125, 125, 113],
#         [130, 130, 118],
#         ...,
#         [ 25,  32,  48],
#         [ 24,  31,  47],
#         [ 24,  31,  47]],
#
#        ...,
#
#        [[ 79,  72,  53],
#         [ 82,  75,  57],
#         [ 84,  77,  59],
#         ...,
#         [129, 118,  88],
#         [128, 116,  90],
#         [127, 115,  93]],
#
#        [[ 86,  79,  60],
#         [ 85,  78,  60],
#         [ 83,  76,  58],
#         ...,
#         [129, 118,  88],
#         [128, 116,  90],
#         [127, 114,  95]],
#
#        [[ 76,  69,  50],
#         [ 69,  62,  44],
#         [ 64,  57,  39],
#         ...,
#         [129, 118,  88],
#         [128, 116,  90],
#         [127, 114,  95]]], shape=(299, 299, 3), dtype=uint8)

# %% [markdown]
# ### Pre-trained convolutional neural networks

# %% [markdown]
# https://www.image-net.org/
#
# https://keras.io/api/applications/

# %%
from tensorflow.keras.applications.xception import Xception
from tensorflow.keras.applications.xception import preprocess_input
from tensorflow.keras.applications.xception import decode_predictions

# %%
model = Xception(weights='imagenet', input_shape=(299, 299, 3))

# %%
X = np.array([X])

# %%
X = preprocess_input(X)

# %%
X[0]
# Out:
# array([[[-0.2235294 , -0.2235294 , -0.31764704],
#         [-0.09019607, -0.09019607, -0.18431371],
#         [-0.10588235, -0.10588235, -0.19999999],
#         ...,
#         [-0.81960785, -0.7647059 , -0.6392157 ],
#         [-0.81960785, -0.7647059 , -0.6392157 ],
#         [-0.827451  , -0.77254903, -0.64705884]],
#
#        [[-0.16862744, -0.16862744, -0.26274508],
#         [-0.05882353, -0.05882353, -0.15294117],
#         [-0.04313725, -0.04313725, -0.1372549 ],
#         ...,
#         [-0.8117647 , -0.75686276, -0.6313726 ],
#         [-0.81960785, -0.7647059 , -0.6392157 ],
#         [-0.81960785, -0.7647059 , -0.6392157 ]],
#
#        [[-0.0745098 , -0.0745098 , -0.16862744],
#         [-0.01960784, -0.01960784, -0.11372548],
#         [ 0.0196079 ,  0.0196079 , -0.0745098 ],
#         ...,
#         [-0.8039216 , -0.7490196 , -0.62352943],
#         [-0.8117647 , -0.75686276, -0.6313726 ],
#         [-0.8117647 , -0.75686276, -0.6313726 ]],
#
#        ...,
#
#        [[-0.38039213, -0.4352941 , -0.58431375],
#         [-0.35686272, -0.41176468, -0.5529412 ],
#         [-0.34117645, -0.3960784 , -0.5372549 ],
#         ...,
#         [ 0.01176476, -0.0745098 , -0.3098039 ],
#         [ 0.00392163, -0.09019607, -0.29411763],
#         [-0.00392157, -0.09803921, -0.27058822]],
#
#        [[-0.32549018, -0.38039213, -0.5294118 ],
#         [-0.3333333 , -0.38823527, -0.5294118 ],
#         [-0.3490196 , -0.40392154, -0.54509807],
#         ...,
#         [ 0.01176476, -0.0745098 , -0.3098039 ],
#         [ 0.00392163, -0.09019607, -0.29411763],
#         [-0.00392157, -0.10588235, -0.25490195]],
#
#        [[-0.40392154, -0.4588235 , -0.60784316],
#         [-0.4588235 , -0.5137255 , -0.654902  ],
#         [-0.4980392 , -0.5529412 , -0.69411767],
#         ...,
#         [ 0.01176476, -0.0745098 , -0.3098039 ],
#         [ 0.00392163, -0.09019607, -0.29411763],
#         [-0.00392157, -0.10588235, -0.25490195]]],
#       shape=(299, 299, 3), dtype=float32)

# %%
pred = model.predict(X)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step

# %%
pred.shape
# Out:
# (1, 1000)

# %%
decode_predictions(pred)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 35363/35363 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# [[('n03595614', 'jersey', np.float32(0.95249814)),
#   ('n04370456', 'sweatshirt', np.float32(0.009788651)),
#   ('n04033995', 'quilt', np.float32(0.0031949643)),
#   ('n03710637', 'maillot', np.float32(0.0012328858)),
#   ('n03188531', 'diaper', np.float32(0.0011855065))]]
